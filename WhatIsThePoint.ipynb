# %%
# %matplotlib inline

import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.mpl_style = 'default' #for styling

# %%
# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
print "Current size:", fig_size
 
# Set figure width to 12 and height to 9
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size
# Out:
# Current size: [6.0, 4.0]

# %%
df = pd.read_csv("data/CA.TXT", header = None)  
df.columns = ['state', 'gender', 'year', 'name', 'count']

# %%
new_df = df.pivot_table(values='count', index='year', columns='name')
try_df = new_df.ix[:,:10]
try_df.plot()

# %%
new_df
# Out:
# name  Aadan  Aaden  Aadhav  Aadhya  Aadi  Aadit  Aaditya  Aadya  Aadyn  Aahan  \
# year
# 1910    NaN    NaN     NaN     NaN   NaN    NaN      NaN    NaN    NaN    NaN
# 1911    NaN    NaN     NaN     NaN   NaN    NaN      NaN    NaN    NaN    NaN
# 1912    NaN    NaN     NaN     NaN   NaN    NaN      NaN    NaN    NaN    NaN
# 1913    NaN    NaN     NaN     NaN   NaN    NaN      NaN    NaN    NaN    NaN
# 1914    NaN    NaN     NaN     NaN   NaN    NaN      NaN    NaN    NaN    NaN
# 1915    NaN    NaN     NaN     NaN   NaN    NaN      NaN    NaN    NaN    NaN
# 1916    NaN    NaN     NaN     NaN   NaN    NaN      NaN    NaN    NaN    NaN
# 1917    NaN    NaN     NaN     NaN   NaN    NaN      NaN    NaN    NaN    NaN
# 1918    NaN    NaN     NaN     NaN   NaN    NaN      NaN    NaN    NaN    NaN
# 1919    NaN    NaN     NaN     NaN   NaN    NaN      NaN    NaN    NaN    NaN
# 1920    NaN    NaN     NaN     NaN   NaN    NaN      NaN    NaN    NaN    NaN
# ...

# %%
new_df['Michael'].sum()
# Out:
# 222620.5

# %% [markdown]
# http://stackoverflow.com/questions/12877189/float64-with-pandas-to-csv

# %%
sample_df = new_df.sample(n=20, axis =1)
sample_df
# Out:
# name  Bebe  Tokio  Cleta  Roosevelt  Amunique  Leigh  Robynne  Cheryll  \
# year
# 1910   NaN    NaN    NaN        NaN       NaN    NaN      NaN      NaN
# 1911   NaN    NaN    NaN        NaN       NaN    NaN      NaN      NaN
# 1912   NaN    NaN    NaN        NaN       NaN    NaN      NaN      NaN
# 1913   NaN    NaN    NaN        NaN       NaN    NaN      NaN      NaN
# 1914   NaN    NaN    NaN        NaN       NaN    NaN      NaN      NaN
# 1915   NaN    NaN    NaN        NaN       NaN    NaN      NaN      NaN
# 1916   NaN    NaN    NaN        NaN       NaN    NaN      NaN      NaN
# 1917   NaN    NaN    NaN        NaN       NaN    NaN      NaN      NaN
# 1918   NaN    NaN    NaN        NaN       NaN    NaN      NaN      NaN
# 1919   NaN    NaN    NaN        NaN       NaN    NaN      NaN      NaN
# 1920   NaN      5    NaN        NaN       NaN    NaN      NaN      NaN
# 1921   NaN    NaN    NaN        NaN       NaN    NaN      NaN      NaN
# ...

# %%
sample_df.plot()

# %%
sum_df = new_df.sum(axis = 0) #return serise, it's hard to work with. So jsut output as csv and get new df
sum_df.to_csv('temp.csv')

# %%
df2 = pd.read_csv("temp.csv", header = None)  
df2.columns = ['name', 'count']

# %%
df2.head
# Out:
# <bound method DataFrame.head of             name   count
# 0          Aadan    18.0
# 1          Aaden   511.0
# 2         Aadhav     6.0
# 3         Aadhya   109.0
# 4           Aadi   110.0
# 5          Aadit    18.0
# 6        Aaditya    61.0
# 7          Aadya    78.0
# 8          Aadyn    14.0
# 9          Aahan    14.0
# 10        Aahana    75.0
# 11         Aahil    18.0
# 12         Aahna     7.0
# 13        Aaiden    55.0
# 14        Aakash   146.0
# 15        Aalaya     5.0
# 16       Aalayah    28.0
# 17        Aaleah    10.0
# 18       Aaleyah    87.0
# 19         Aalia    25.0
# 20        Aaliah   133.0
# 21       Aalijah     5.0
# 22        Aaliya   103.0
# 23       Aaliyah  8134.0
# 24       Aaliyha     5.0
# 25        Aalyah   106.0
# 26       Aalyiah    34.0
# 27        Aamina     5.0
# 28       Aaminah     5.0
# 29         Aamir   142.0
# ...          ...     ...
# 18705      Zulay    27.0
# 18706    Zuleica    20.0
# 18707    Zuleidy     5.0
# ...

# %%
df2[df2['name'] == "Michael"] ##WHAT???? why there's .5?
# Out:
#           name     count
# 12643  Michael  222620.5

# %% [markdown]
# It's pandas' inherent problem. Just let go~
# http://stackoverflow.com/questions/12877189/float64-with-pandas-to-csv

# %%
df2['count'] = df2['count'].round(0)

# %%
df2.sort(['count'], ascending=False)[:10] #top 10
# Out:
#               name   count
# 12643      Michael  222620
# 4375         David  201488
# 14786       Robert  193531
# 8658          John  179104
# 7797         James  161892
# 4193        Daniel  153994
# 17990      William  142717
# 14689      Richard  129206
# 3600   Christopher  122007
# 8820        Joseph  113366

# %% [markdown]
# make the list of top XXXX
#
# BAD NEWS! I want 2 lists of male and female top names!!!
# I am going to cheat.
# 1. Get the top 50 names list from df2
# 2. Map it back to the original df to generate male list and female list
# 3. Using two lists as indext to Access the year by year data from new_df
